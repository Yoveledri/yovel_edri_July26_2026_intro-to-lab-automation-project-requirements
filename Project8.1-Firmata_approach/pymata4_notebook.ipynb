# %%
# %pip install pymata4
# Out:
# Collecting pymata4
#   Downloading pymata4-1.15-py2.py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: pyserial in c:\Users\yovele\Documents\gui_for_course\.venv_lab_automation\Lib\site-packages (from pymata4) (3.5)
# Downloading pymata4-1.15-py2.py3-none-any.whl (24 kB)
# Installing collected packages: pymata4
# Successfully installed pymata4-1.15
# Note: you may need to restart the kernel to use updated packages.

# %%
import time
import sys
from pymata4 import pymata4

# %%
board = pymata4.Pymata4(com_port="COM4")
# Out:
# pymata4:  Version 1.15
#
# Copyright (c) 2020 Alan Yorinks All Rights Reserved.
#
# Opening COM4...
#
# Waiting 4 seconds(arduino_wait) for Arduino devices to reset...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 board = pymata4.Pymata4(com_port="COM4")
#
# File c:\Users\yovele\Documents\gui_for_course\.venv_lab_automation\Lib\site-packages\pymata4\pymata4.py:242, in Pymata4.__init__(self, com_port, baud_rate, arduino_instance_id, arduino_wait, sleep_tune, shutdown_on_exception, ip_address, ip_port)
#     239 else:
#     240     # com_port specified - set com_port and baud rate
#     241     try:
# --> 242         self._manual_open()
#     243     except KeyboardInterrupt:
#     244         if self.shutdown_on_exception:
#
# File c:\Users\yovele\Documents\gui_for_course\.venv_lab_automation\Lib\site-packages\pymata4\pymata4.py:434, in Pymata4._manual_open(self)
#     431 i_am_here = list(i_am_here)
#     433 if len(i_am_here) != 4:
# --> 434     raise RuntimeError('Invalid Arduino ID reply length')
#     436 # check sysex command is I_AM_HERE
#     437 if i_am_here[1] != PrivateConstants.I_AM_HERE:
#
# RuntimeError: Invalid Arduino ID reply length

# %%
LED_PIN = 4
board.set_pin_mode_digital_output(LED_PIN)

# %%
board.digital_write(LED_PIN, 0)

# %%
# board.shutdown() ## caused crashes, do not uncomment! reset kernel to disconnect instead.
